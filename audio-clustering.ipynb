# %% [markdown]
# # Кластеризация аудио-сигналов
#
# Выполнил студент группы 9381 Колованов Родион Алексеевич.

# %% [markdown]
# ### Загрузка аудиофайлов
#
# Для начала подключим нужные библиотеки:

# %%
from pydub import AudioSegment
import scipy.fft
import numpy as np
import more_itertools as mit
import random
import copy
import csv

# %% [markdown]
# Загрузим аудиосигналы из файлов формата mp3:

# %%
signals = []
filepath_template = "data/{}.mp3"

print("Загрузка аудиофайлов...")

for i in range(1, 125):
    if i < 10:
        i = "0{}".format(i)
    audiofile = AudioSegment.from_mp3(filepath_template.format(i)).set_channels(1)
    signals.append(np.array(audiofile.get_array_of_samples()))
    print("  {}".format(filepath_template.format(i)))

print("Загрузка аудиофайлов завершена.")
# Out:
# Загрузка аудиофайлов...
#   data/01.mp3
#   data/02.mp3
#   data/03.mp3
#   data/04.mp3
#   data/05.mp3
#   data/06.mp3
#   data/07.mp3
#   data/08.mp3
#   data/09.mp3
#   data/10.mp3
#   data/11.mp3
#   data/12.mp3
#   data/13.mp3
#   data/14.mp3
#   data/15.mp3
#   data/16.mp3
#   data/17.mp3
#   data/18.mp3
#   data/19.mp3
#   data/20.mp3
#   data/21.mp3
#   data/22.mp3
#   data/23.mp3
#   data/24.mp3
#   data/25.mp3
#   data/26.mp3
#   data/27.mp3
#   data/28.mp3
#   data/29.mp3
#   data/30.mp3
#   data/31.mp3
#   data/32.mp3
#   data/33.mp3
#   data/34.mp3
#   data/35.mp3
#   data/36.mp3
#   data/37.mp3
#   data/38.mp3
#   data/39.mp3
#   data/40.mp3
#   data/41.mp3
#   data/42.mp3
#   data/43.mp3
#   data/44.mp3
#   data/45.mp3
#   data/46.mp3
#   data/47.mp3
#   data/48.mp3
#   data/49.mp3
#   data/50.mp3
#   data/51.mp3
#   data/52.mp3
#   data/53.mp3
#   data/54.mp3
#   data/55.mp3
#   data/56.mp3
#   data/57.mp3
#   data/58.mp3
#   data/59.mp3
#   data/60.mp3
#   data/61.mp3
#   data/62.mp3
#   data/63.mp3
#   data/64.mp3
#   data/65.mp3
#   data/66.mp3
#   data/67.mp3
#   data/68.mp3
#   data/69.mp3
#   data/70.mp3
#   data/71.mp3
#   data/72.mp3
#   data/73.mp3
#   data/74.mp3
#   data/75.mp3
#   data/76.mp3
#   data/77.mp3
#   data/78.mp3
#   data/79.mp3
#   data/80.mp3
#   data/81.mp3
#   data/82.mp3
#   data/83.mp3
#   data/84.mp3
#   data/85.mp3
#   data/86.mp3
#   data/87.mp3
#   data/88.mp3
#   data/89.mp3
#   data/90.mp3
#   data/91.mp3
#   data/92.mp3
#   data/93.mp3
#   data/94.mp3
#   data/95.mp3
#   data/96.mp3
#   data/97.mp3
#   data/98.mp3
#   data/99.mp3
#   data/100.mp3
#   data/101.mp3
#   data/102.mp3
#   data/103.mp3
#   data/104.mp3
#   data/105.mp3
#   data/106.mp3
#   data/107.mp3
#   data/108.mp3
#   data/109.mp3
#   data/110.mp3
#   data/111.mp3
#   data/112.mp3
#   data/113.mp3
#   data/114.mp3
#   data/115.mp3
#   data/116.mp3
#   data/117.mp3
#   data/118.mp3
#   data/119.mp3
#   data/120.mp3
#   data/121.mp3
#   data/122.mp3
#   data/123.mp3
#   data/124.mp3
# Загрузка аудиофайлов завершена.

# %% [markdown]
# Зададим параметры деления сигнала на окна:

# %%
dimension = 256
window_offset = 256
suitable_frame_threshold = 0.1

# %% [markdown]
# Получим амплитудные спектры сигналов:

# %%
amplitude_spectrals = []

for signal in signals:
    print("Обработка сигнала №{}...".format(len(amplitude_spectrals) + 1))
    
    signal_intervals = list(mit.windowed(signal, fillvalue=0.0, n=dimension, step=window_offset))

    print("  Общее количество кадров: {}".format(len(signal_intervals)))

    bound = 0.0
    for interval in signal_intervals:
        m = np.max(interval)
        if m > bound:
            bound = m
    bound *= suitable_frame_threshold

    signal_intervals = list(filter(lambda i: np.max(i) > bound, signal_intervals))
    
    print("  Количество подходящих кадров: {}".format(len(signal_intervals)))

    signal_intervals = list(map(lambda interval: scipy.fft.fft(interval * np.hamming(len(interval))), signal_intervals))
    amplitude_spectral = [[np.abs(i) for i in interval[:dimension//2]] for interval in signal_intervals]
    amplitude_spectral_mean = [0 for i in range(dimension // 2)]
    
    for amplitude_spectral_interval in amplitude_spectral:
        for i in range(dimension // 2):
            amplitude_spectral_mean[i] += amplitude_spectral_interval[i]

    for i in range(dimension // 2):
        amplitude_spectral_mean[i] /= len(signal_intervals)
    
    amplitude_spectrals.append(amplitude_spectral_mean)
# Out:
# Обработка сигнала №1...
#   Общее количество кадров: 36990
#   Количество подходящих кадров: 31334
# Обработка сигнала №2...
#   Общее количество кадров: 28886
#   Количество подходящих кадров: 23696
# Обработка сигнала №3...
#   Общее количество кадров: 42269
#   Количество подходящих кадров: 35558
# Обработка сигнала №4...
#   Общее количество кадров: 61641
#   Количество подходящих кадров: 31474
# Обработка сигнала №5...
#   Общее количество кадров: 22487
#   Количество подходящих кадров: 12769
# Обработка сигнала №6...
#   Общее количество кадров: 30659
#   Количество подходящих кадров: 28745
# Обработка сигнала №7...
#   Общее количество кадров: 51831
#   Количество подходящих кадров: 35567
# Обработка сигнала №8...
#   Общее количество кадров: 24876
#   Количество подходящих кадров: 22399
# Обработка сигнала №9...
#   Общее количество кадров: 34556
#   Количество подходящих кадров: 28174
# Обработка сигнала №10...
#   Общее количество кадров: 36657
#   Количество подходящих кадров: 22416
# Обработка сигнала №11...
#   Общее количество кадров: 24476
#   Количество подходящих кадров: 19394
# Обработка сигнала №12...
#   Общее количество кадров: 36900
#   Количество подходящих кадров: 26269
# Обработка сигнала №13...
#   Общее количество кадров: 28422
#   Количество подходящих кадров: 16746
# Обработка сигнала №14...
#   Общее количество кадров: 32963
#   Количество подходящих кадров: 27735
# Обработка сигнала №15...
#   Общее количество кадров: 8982
#   Количество подходящих кадров: 7390
# Обработка сигнала №16...
#   Общее количество кадров: 35996
#   Количество подходящих кадров: 29558
# Обработка сигнала №17...
#   Общее количество кадров: 43767
#   Количество подходящих кадров: 31246
# Обработка сигнала №18...
#   Общее количество кадров: 24323
#   Количество подходящих кадров: 19462
# Обработка сигнала №19...
#   Общее количество кадров: 34952
#   Количество подходящих кадров: 26617
# Обработка сигнала №20...
#   Общее количество кадров: 56462
#   Количество подходящих кадров: 23621
# Обработка сигнала №21...
#   Общее количество кадров: 43929
#   Количество подходящих кадров: 29249
# Обработка сигнала №22...
#   Общее количество кадров: 27977
#   Количество подходящих кадров: 24929
# Обработка сигнала №23...
#   Общее количество кадров: 33192
#   Количество подходящих кадров: 24228
# Обработка сигнала №24...
#   Общее количество кадров: 28773
#   Количество подходящих кадров: 24048
# Обработка сигнала №25...
#   Общее количество кадров: 32904
#   Количество подходящих кадров: 21341
# Обработка сигнала №26...
#   Общее количество кадров: 11889
#   Количество подходящих кадров: 8351
# Обработка сигнала №27...
#   Общее количество кадров: 43565
#   Количество подходящих кадров: 28899
# Обработка сигнала №28...
#   Общее количество кадров: 52916
#   Количество подходящих кадров: 38198
# Обработка сигнала №29...
#   Общее количество кадров: 37121
#   Количество подходящих кадров: 27398
# Обработка сигнала №30...
#   Общее количество кадров: 35622
#   Количество подходящих кадров: 27254
# Обработка сигнала №31...
#   Общее количество кадров: 27486
#   Количество подходящих кадров: 16520
# Обработка сигнала №32...
#   Общее количество кадров: 41819
#   Количество подходящих кадров: 32123
# Обработка сигнала №33...
#   Общее количество кадров: 53294
#   Количество подходящих кадров: 44560
# Обработка сигнала №34...
#   Общее количество кадров: 24327
#   Количество подходящих кадров: 18072
# Обработка сигнала №35...
#   Общее количество кадров: 28670
#   Количество подходящих кадров: 19678
# Обработка сигнала №36...
#   Общее количество кадров: 25434
#   Количество подходящих кадров: 17054
# Обработка сигнала №37...
#   Общее количество кадров: 54648
#   Количество подходящих кадров: 20056
# Обработка сигнала №38...
#   Общее количество кадров: 35181
#   Количество подходящих кадров: 20816
# Обработка сигнала №39...
#   Общее количество кадров: 56012
#   Количество подходящих кадров: 24011
# Обработка сигнала №40...
#   Общее количество кадров: 40874
#   Количество подходящих кадров: 17661
# Обработка сигнала №41...
#   Общее количество кадров: 47354
#   Количество подходящих кадров: 28620
# Обработка сигнала №42...
#   Общее количество кадров: 41013
#   Количество подходящих кадров: 22911
# Обработка сигнала №43...
#   Общее количество кадров: 46944
#   Количество подходящих кадров: 19749
# Обработка сигнала №44...
#   Общее количество кадров: 48546
#   Количество подходящих кадров: 16302
# Обработка сигнала №45...
#   Общее количество кадров: 35289
#   Количество подходящих кадров: 21679
# Обработка сигнала №46...
#   Общее количество кадров: 28557
#   Количество подходящих кадров: 15240
# Обработка сигнала №47...
#   Общее количество кадров: 67190
#   Количество подходящих кадров: 33509
# Обработка сигнала №48...
#   Общее количество кадров: 47655
#   Количество подходящих кадров: 19876
# Обработка сигнала №49...
#   Общее количество кадров: 21578
#   Количество подходящих кадров: 7146
# Обработка сигнала №50...
#   Общее количество кадров: 57686
#   Количество подходящих кадров: 20113
# Обработка сигнала №51...
#   Общее количество кадров: 9905
#   Количество подходящих кадров: 4373
# Обработка сигнала №52...
#   Общее количество кадров: 66654
#   Количество подходящих кадров: 36956
# Обработка сигнала №53...
#   Общее количество кадров: 81180
#   Количество подходящих кадров: 19573
# Обработка сигнала №54...
#   Общее количество кадров: 5859
#   Количество подходящих кадров: 4246
# Обработка сигнала №55...
#   Общее количество кадров: 30578
#   Количество подходящих кадров: 15811
# Обработка сигнала №56...
#   Общее количество кадров: 8348
#   Количество подходящих кадров: 7064
# Обработка сигнала №57...
#   Общее количество кадров: 10778
#   Количество подходящих кадров: 7761
# Обработка сигнала №58...
#   Общее количество кадров: 21965
#   Количество подходящих кадров: 7886
# Обработка сигнала №59...
#   Общее количество кадров: 19040
#   Количество подходящих кадров: 15584
# Обработка сигнала №60...
#   Общее количество кадров: 103158
#   Количество подходящих кадров: 38032
# Обработка сигнала №61...
#   Общее количество кадров: 30690
#   Количество подходящих кадров: 20043
# Обработка сигнала №62...
#   Общее количество кадров: 56511
#   Количество подходящих кадров: 27414
# Обработка сигнала №63...
#   Общее количество кадров: 18068
#   Количество подходящих кадров: 12928
# Обработка сигнала №64...
#   Общее количество кадров: 21524
#   Количество подходящих кадров: 13703
# Обработка сигнала №65...
#   Общее количество кадров: 50108
#   Количество подходящих кадров: 26677
# Обработка сигнала №66...
#   Общее количество кадров: 109188
#   Количество подходящих кадров: 76432
# Обработка сигнала №67...
#   Общее количество кадров: 83561
#   Количество подходящих кадров: 26720
# Обработка сигнала №68...
#   Общее количество кадров: 207815
#   Количество подходящих кадров: 138549
# Обработка сигнала №69...
#   Общее количество кадров: 194090
#   Количество подходящих кадров: 48518
# Обработка сигнала №70...
#   Общее количество кадров: 81045
#   Количество подходящих кадров: 18587
# Обработка сигнала №71...
#   Общее количество кадров: 47417
#   Количество подходящих кадров: 28877
# Обработка сигнала №72...
#   Общее количество кадров: 67194
#   Количество подходящих кадров: 34662
# Обработка сигнала №73...
#   Общее количество кадров: 19701
#   Количество подходящих кадров: 10416
# Обработка сигнала №74...
#   Общее количество кадров: 50225
#   Количество подходящих кадров: 26667
# Обработка сигнала №75...
#   Общее количество кадров: 40815
#   Количество подходящих кадров: 17960
# Обработка сигнала №76...
#   Общее количество кадров: 20840
#   Количество подходящих кадров: 13485
# Обработка сигнала №77...
#   Общее количество кадров: 55760
#   Количество подходящих кадров: 24266
# Обработка сигнала №78...
#   Общее количество кадров: 26708
#   Количество подходящих кадров: 24544
# Обработка сигнала №79...
#   Общее количество кадров: 37269
#   Количество подходящих кадров: 25600
# Обработка сигнала №80...
#   Общее количество кадров: 18293
#   Количество подходящих кадров: 12488
# Обработка сигнала №81...
#   Общее количество кадров: 45747
#   Количество подходящих кадров: 19209
# Обработка сигнала №82...
#   Общее количество кадров: 45648
#   Количество подходящих кадров: 32364
# Обработка сигнала №83...
#   Общее количество кадров: 62487
#   Количество подходящих кадров: 18070
# Обработка сигнала №84...
#   Общее количество кадров: 59873
#   Количество подходящих кадров: 32312
# Обработка сигнала №85...
#   Общее количество кадров: 48713
#   Количество подходящих кадров: 35137
# Обработка сигнала №86...
#   Общее количество кадров: 12312
#   Количество подходящих кадров: 11352
# Обработка сигнала №87...
#   Общее количество кадров: 16988
#   Количество подходящих кадров: 12730
# Обработка сигнала №88...
#   Общее количество кадров: 5904
#   Количество подходящих кадров: 4301
# Обработка сигнала №89...
#   Общее количество кадров: 31568
#   Количество подходящих кадров: 22467
# Обработка сигнала №90...
#   Общее количество кадров: 42417
#   Количество подходящих кадров: 14671
# Обработка сигнала №91...
#   Общее количество кадров: 26213
#   Количество подходящих кадров: 8054
# Обработка сигнала №92...
#   Общее количество кадров: 46170
#   Количество подходящих кадров: 25611
# Обработка сигнала №93...
#   Общее количество кадров: 31824
#   Количество подходящих кадров: 17340
# Обработка сигнала №94...
#   Общее количество кадров: 24224
#   Количество подходящих кадров: 15873
# Обработка сигнала №95...
#   Общее количество кадров: 10935
#   Количество подходящих кадров: 8994
# Обработка сигнала №96...
#   Общее количество кадров: 97074
#   Количество подходящих кадров: 38538
# Обработка сигнала №97...
#   Общее количество кадров: 142331
#   Количество подходящих кадров: 64378
# Обработка сигнала №98...
#   Общее количество кадров: 75195
#   Количество подходящих кадров: 41115
# Обработка сигнала №99...
#   Общее количество кадров: 52151
#   Количество подходящих кадров: 22938
# Обработка сигнала №100...
#   Общее количество кадров: 98055
#   Количество подходящих кадров: 42474
# Обработка сигнала №101...
#   Общее количество кадров: 34938
#   Количество подходящих кадров: 13077
# Обработка сигнала №102...
#   Общее количество кадров: 35712
#   Количество подходящих кадров: 10668
# Обработка сигнала №103...
#   Общее количество кадров: 260955
#   Количество подходящих кадров: 141201
# Обработка сигнала №104...
#   Общее количество кадров: 42894
#   Количество подходящих кадров: 30232
# Обработка сигнала №105...
#   Общее количество кадров: 26852
#   Количество подходящих кадров: 5732
# Обработка сигнала №106...
#   Общее количество кадров: 77504
#   Количество подходящих кадров: 52834
# Обработка сигнала №107...
#   Общее количество кадров: 25848
#   Количество подходящих кадров: 19390
# Обработка сигнала №108...
#   Общее количество кадров: 40374
#   Количество подходящих кадров: 35148
# Обработка сигнала №109...
#   Общее количество кадров: 70493
#   Количество подходящих кадров: 28994
# Обработка сигнала №110...
#   Общее количество кадров: 53253
#   Количество подходящих кадров: 14349
# Обработка сигнала №111...
#   Общее количество кадров: 111497
#   Количество подходящих кадров: 33083
# Обработка сигнала №112...
#   Общее количество кадров: 30632
#   Количество подходящих кадров: 17297
# Обработка сигнала №113...
#   Общее количество кадров: 78228
#   Количество подходящих кадров: 30578
# Обработка сигнала №114...
#   Общее количество кадров: 90581
#   Количество подходящих кадров: 5918
# Обработка сигнала №115...
#   Общее количество кадров: 28827
#   Количество подходящих кадров: 12988
# Обработка сигнала №116...
#   Общее количество кадров: 68864
#   Количество подходящих кадров: 24107
# Обработка сигнала №117...
#   Общее количество кадров: 19053
#   Количество подходящих кадров: 7552
# Обработка сигнала №118...
#   Общее количество кадров: 35762
#   Количество подходящих кадров: 13724
# Обработка сигнала №119...
#   Общее количество кадров: 164714
#   Количество подходящих кадров: 48573
# Обработка сигнала №120...
#   Общее количество кадров: 111047
#   Количество подходящих кадров: 59639
# Обработка сигнала №121...
#   Общее количество кадров: 70412
#   Количество подходящих кадров: 31233
# Обработка сигнала №122...
#   Общее количество кадров: 199350
#   Количество подходящих кадров: 49946
# Обработка сигнала №123...
#   Общее количество кадров: 52191
#   Количество подходящих кадров: 34259
# Обработка сигнала №124...
#   Общее количество кадров: 92664
#   Количество подходящих кадров: 45648

# %% [markdown]
# Выполнил кластеризацию сигналов по их ампилтудным спектрам:

# %%
def update_centers(data, clusters, centers):
    dimension = len(data[0])
    centers_length = len(centers)
    
    for i in range(centers_length):
        for j in range(dimension):
            if len(clusters[i]) != 0:
                component = 0.0
                for k in range(len(clusters[i])): 
                    component += data[clusters[i][k]][j]
                component /= len(clusters[i])
                
                centers[i][j] = component

def distribute_data(data, centers):
    dimension = len(data[0])
    data_length = len(data)
    centers_length = len(centers)
    clusters = [[] for i in range(centers_length)]

    for i in range(data_length):
        min_distance = float('inf')
        situable_cluster = None
        
        for j in range(centers_length):
            distance = 0.0
            for k in range(dimension):
                distance += (data[i][k] - centers[j][k]) ** 2
            distance = np.sqrt(distance)
            
            if distance < min_distance:
                min_distance = distance
                situable_cluster = j

        clusters[situable_cluster].append(i)

    return clusters

def clusterization(data, k): 
    dimension = len(data[0])  

    indexes = []
    for i in range(k):
        r = random.randint(0, k)
        while r in indexes:
            r = random.randint(0, k)
        indexes.append(r)
    
    previous_centers = None
    centers = [copy.deepcopy(data[i]) for i in indexes]
    clusters = distribute_data(data, centers)
        
    while centers != previous_centers:
        previous_centers = copy.deepcopy(centers)
        update_centers(data, clusters, centers)
        clusters = distribute_data(data, centers)
        
    return clusters, centers

def cluster_cohesion(data, centers, clusters):
    s = 0.0
    for j in range(len(clusters)):
        for i in range(len(clusters[j])):
            d = 0.0
            for k in range(len(data[clusters[j][i]])):
                d += np.abs(data[clusters[j][i]][k] - centers[j][k]) ** 2
            s += d
    return s / len(clusters)

# %% [markdown]
# Найдем наилучшую кластеризацию по минимальной компакстности кластеров:

# %%
iterations = 99
clusters, centers = clusterization(amplitude_spectrals, 5)
min_cluster_cohesion = cluster_cohesion(amplitude_spectrals, centers, clusters)

print("Попытка №1, компактность: {}".format(min_cluster_cohesion))

for i in range(iterations):
    temp_clusters, temp_centers = clusterization(amplitude_spectrals, 5)
    temp_cluster_cohesion = cluster_cohesion(amplitude_spectrals, temp_centers, temp_clusters)
    
    print("Попытка №{}, компактность: {}".format(i + 2, temp_cluster_cohesion))
    
    if temp_cluster_cohesion < min_cluster_cohesion:
        clusters, centers = temp_clusters, temp_centers
        min_cluster_cohesion = temp_cluster_cohesion
# Out:
# Попытка №1, компактность: 81130859636.09238
# Попытка №2, компактность: 77546419557.95602
# Попытка №3, компактность: 77546419557.95595
# Попытка №4, компактность: 81130859636.09233
# Попытка №5, компактность: 72468449909.30411
# Попытка №6, компактность: 87703518638.19717
# Попытка №7, компактность: 72468449909.30408
# Попытка №8, компактность: 81130859636.09232
# Попытка №9, компактность: 81130859636.09235
# Попытка №10, компактность: 72468449909.30406
# Попытка №11, компактность: 77546419557.956
# Попытка №12, компактность: 81893764024.84088
# Попытка №13, компактность: 81130859636.09233
# Попытка №14, компактность: 77546419557.956
# Попытка №15, компактность: 81130859636.09235
# Попытка №16, компактность: 77546419557.95602
# Попытка №17, компактность: 87703518638.19724
# Попытка №18, компактность: 72468449909.3041
# Попытка №19, компактность: 81893764024.84088
# Попытка №20, компактность: 81130859636.09232
# Попытка №21, компактность: 72468449909.30411
# Попытка №22, компактность: 81893764024.84087
# Попытка №23, компактность: 72468449909.30406
# Попытка №24, компактность: 72468449909.30406
# Попытка №25, компактность: 77546419557.95601
# Попытка №26, компактность: 81130859636.09235
# Попытка №27, компактность: 81893764024.84088
# Попытка №28, компактность: 81130859636.09236
# Попытка №29, компактность: 77546419557.95595
# Попытка №30, компактность: 77546419557.95601
# Попытка №31, компактность: 81130859636.09236
# Попытка №32, компактность: 77546419557.95601
# Попытка №33, компактность: 77546419557.95601
# Попытка №34, компактность: 81130859636.09238
# Попытка №35, компактность: 77546419557.95598
# Попытка №36, компактность: 81893764024.8409
# Попытка №37, компактность: 72468449909.30406
# Попытка №38, компактность: 87703518638.19717
# Попытка №39, компактность: 87703518638.19717
# Попытка №40, компактность: 81130859636.09235
# Попытка №41, компактность: 72468449909.30406
# Попытка №42, компактность: 81893764024.84088
# Попытка №43, компактность: 81893764024.84085
# Попытка №44, компактность: 77546419557.95596
# Попытка №45, компактность: 77546419557.95598
# Попытка №46, компактность: 77546419557.95595
# Попытка №47, компактность: 81130859636.09236
# Попытка №48, компактность: 87703518638.19717
# Попытка №49, компактность: 72468449909.30411
# Попытка №50, компактность: 87703518638.19719
# Попытка №51, компактность: 77546419557.95596
# Попытка №52, компактность: 81130859636.09238
# Попытка №53, компактность: 77546419557.95598
# Попытка №54, компактность: 81130859636.09233
# Попытка №55, компактность: 81893764024.8409
# Попытка №56, компактность: 77546419557.95592
# Попытка №57, компактность: 81893764024.8409
# Попытка №58, компактность: 87703518638.19724
# Попытка №59, компактность: 81893764024.84087
# Попытка №60, компактность: 81130859636.09235
# Попытка №61, компактность: 81130859636.09236
# Попытка №62, компактность: 81130859636.09232
# Попытка №63, компактность: 81130859636.09232
# Попытка №64, компактность: 77546419557.95598
# Попытка №65, компактность: 81893764024.84087
# Попытка №66, компактность: 77546419557.95596
# Попытка №67, компактность: 77546419557.95596
# Попытка №68, компактность: 77546419557.956
# Попытка №69, компактность: 87703518638.19719
# Попытка №70, компактность: 81893764024.84085
# Попытка №71, компактность: 87703518638.1972
# Попытка №72, компактность: 87703518638.19717
# Попытка №73, компактность: 81893764024.84085
# Попытка №74, компактность: 77546419557.95596
# Попытка №75, компактность: 81130859636.09235
# Попытка №76, компактность: 87703518638.19717
# Попытка №77, компактность: 77546419557.95596
# Попытка №78, компактность: 77546419557.95602
# Попытка №79, компактность: 77546419557.95596
# Попытка №80, компактность: 81130859636.09232
# Попытка №81, компактность: 81893764024.84088
# Попытка №82, компактность: 77546419557.956
# Попытка №83, компактность: 87703518638.19717
# Попытка №84, компактность: 77546419557.956
# Попытка №85, компактность: 72468449909.30411
# Попытка №86, компактность: 81893764024.84088
# Попытка №87, компактность: 77546419557.95595
# Попытка №88, компактность: 81893764024.8409
# Попытка №89, компактность: 77546419557.95602
# Попытка №90, компактность: 81893764024.84088
# Попытка №91, компактность: 87703518638.19717
# Попытка №92, компактность: 72468449909.30408
# Попытка №93, компактность: 77546419557.95602
# Попытка №94, компактность: 81893764024.84085
# Попытка №95, компактность: 77546419557.95601
# Попытка №96, компактность: 77546419557.95602
# Попытка №97, компактность: 77546419557.95596
# Попытка №98, компактность: 81893764024.8409
# Попытка №99, компактность: 81130859636.09238
# Попытка №100, компактность: 77546419557.95601

# %% [markdown]
# Выведем результаты:

# %%
def get_filename_by_index(i):
    i += 1
    if i < 10:
        return "0{}.mp3".format(i)
    return "{}.mp3".format(i)

# %%
audio_clusters = {}
for i in range(len(clusters)):
    for j in range(len(clusters[i])):
        audio_clusters[get_filename_by_index(clusters[i][j])] = i + 1

print("Компактность кластеров: {}".format(min_cluster_cohesion))
print("Распределение номеров аудиосигналов по кластерам:\n{}".format(audio_clusters))
# Out:
# Компактность кластеров: 72468449909.30406
# Распределение номеров аудиосигналов по кластерам:
# {'02.mp3': 1, '05.mp3': 1, '08.mp3': 1, '11.mp3': 1, '28.mp3': 1, '42.mp3': 1, '54.mp3': 1, '55.mp3': 1, '57.mp3': 1, '58.mp3': 1, '59.mp3': 1, '61.mp3': 1, '62.mp3': 1, '63.mp3': 1, '67.mp3': 1, '80.mp3': 1, '83.mp3': 1, '86.mp3': 1, '87.mp3': 1, '89.mp3': 1, '91.mp3': 1, '93.mp3': 1, '95.mp3': 1, '104.mp3': 1, '19.mp3': 2, '24.mp3': 2, '30.mp3': 2, '33.mp3': 2, '38.mp3': 2, '41.mp3': 2, '46.mp3': 2, '49.mp3': 2, '50.mp3': 2, '51.mp3': 2, '52.mp3': 2, '69.mp3': 2, '71.mp3': 2, '73.mp3': 2, '81.mp3': 2, '85.mp3': 2, '88.mp3': 2, '90.mp3': 2, '92.mp3': 2, '97.mp3': 2, '110.mp3': 2, '14.mp3': 3, '16.mp3': 3, '21.mp3': 3, '22.mp3': 3, '23.mp3': 3, '106.mp3': 3, '108.mp3': 3, '01.mp3': 4, '03.mp3': 4, '04.mp3': 4, '06.mp3': 4, '07.mp3': 4, '09.mp3': 4, '10.mp3': 4, '12.mp3': 4, '15.mp3': 4, '17.mp3': 4, '18.mp3': 4, '20.mp3': 4, '26.mp3': 4, '27.mp3': 4, '29.mp3': 4, '32.mp3': 4, '34.mp3': 4, '66.mp3': 4, '68.mp3': 4, '98.mp3': 4, '99.mp3': 4, '100.mp3': 4, '101.mp3': 4, '102.mp3': 4, '103.mp3': 4, '107.mp3': 4, '111.mp3': 4, '112.mp3': 4, '113.mp3': 4, '114.mp3': 4, '115.mp3': 4, '119.mp3': 4, '120.mp3': 4, '121.mp3': 4, '122.mp3': 4, '123.mp3': 4, '13.mp3': 5, '25.mp3': 5, '31.mp3': 5, '35.mp3': 5, '36.mp3': 5, '37.mp3': 5, '39.mp3': 5, '40.mp3': 5, '43.mp3': 5, '44.mp3': 5, '45.mp3': 5, '47.mp3': 5, '48.mp3': 5, '53.mp3': 5, '56.mp3': 5, '60.mp3': 5, '64.mp3': 5, '65.mp3': 5, '70.mp3': 5, '72.mp3': 5, '74.mp3': 5, '75.mp3': 5, '76.mp3': 5, '77.mp3': 5, '78.mp3': 5, '79.mp3': 5, '82.mp3': 5, '84.mp3': 5, '94.mp3': 5, '96.mp3': 5, '105.mp3': 5, '109.mp3': 5, '116.mp3': 5, '117.mp3': 5, '118.mp3': 5, '124.mp3': 5}
# [[1, 4, 7, 10, 27, 41, 53, 54, 56, 57, 58, 60, 61, 62, 66, 79, 82, 85, 86, 88, 90, 92, 94, 103], [18, 23, 29, 32, 37, 40, 45, 48, 49, 50, 51, 68, 70, 72, 80, 84, 87, 89, 91, 96, 109], [13, 15, 20, 21, 22, 105, 107], [0, 2, 3, 5, 6, 8, 9, 11, 14, 16, 17, 19, 25, 26, 28, 31, 33, 65, 67, 97, 98, 99, 100, 101, 102, 106, 110, 111, 112, 113, 114, 118, 119, 120, 121, 122], [12, 24, 30, 34, 35, 36, 38, 39, 42, 43, 44, 46, 47, 52, 55, 59, 63, 64, 69, 71, 73, 74, 75, 76, 77, 78, 81, 83, 93, 95, 104, 108, 115, 116, 117, 123]]

# %% [markdown]
# Сохраним результаты в CSV:

# %%
with open('results.csv', 'w', newline='') as file:
    writer = csv.writer(file, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for i in range(len(signals)):
        filename = get_filename_by_index(i)
        writer.writerow([filename, audio_clusters[filename]])
